# %% [markdown]
#  # Dataset Description
#  The dataset represents the midterm examination scores of students from the "ALPHA" section in their second semester. Each row corresponds to an individual student, and the columns contain information such as serial number, section name, and scores in six different subjects: DV (Digital VLSI), M-II (Mathematics-II), PP (Programming Principles), BEEE (Basic Electrical and Electronics Engineering), FL (Formal Languages), and FIMS (Fundamentals of Information Management Systems). The dataset provides numerical marks for each subject, allowing for performance evaluation.
#
# The "S.NO" column uniquely identifies students, while the "SECTION" column confirms that all students belong to the same section. The dataset mainly consists of integer values, representing scores obtained by students in each subject. These marks help in assessing academic performance across different domains of study. By analyzing the distribution of marks, educators can identify trends in student learning outcomes.
#
# A primary use of this dataset would be to compare student performance across various subjects, identifying areas where students excel or struggle. For instance, some subjects may show consistently high scores, indicating better understanding, while others may have lower averages, signaling the need for improved teaching strategies. Analyzing subject-wise performance could also help in modifying the curriculum or providing targeted interventions for weaker students.
#
# Additionally, this dataset could be utilized for ranking students based on their overall scores or individual subject scores. It can also help determine the highest and lowest marks achieved in each subject. Trends in performance could indicate whether a subject is particularly challenging for students or if certain students require additional academic support.
#
# This data can also be useful for predicting future performance in final exams by analyzing correlations between midterm scores and overall academic success. By identifying at-risk students early, faculty members can provide necessary remedial support, improving overall class performance. Moreover, statistical techniques such as mean, median, and standard deviation can be applied to understand score distributions.

# %%
import pandas as pd
data=pd.read_csv("MIDMARKS(1).csv") 
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data['SECTION']=data['SECTION'].fillna('ZETA') 
data['SECTION']=data['SECTION'].replace('','ZETA')
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data.replace('o',0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data.replace('I',1)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data.replace('II',11)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data['DV'].replace('o',0)
# Out:
# 0      12
# 1      19
# 2      18
# 3      15
# 4      18
#        ..
# 713    19
# 714    12
# 715    17
# 716    12
# 717    19
# Name: DV, Length: 718, dtype: object

# %%
data.replace('A',0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data['DV'].replace('A',0)
# Out:
# 0      12
# 1      19
# 2      18
# 3      15
# 4      18
#        ..
# 713    19
# 714    12
# 715    17
# 716    12
# 717    19
# Name: DV, Length: 718, dtype: object

# %%
data.replace('AB',0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data.replace('MP',0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]>

# %%
data.info('M-II')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  718 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %%
data[data['SECTION']=='ALPHA']['DV'].replace('o',0)
# Out:
# 0     12
# 1     19
# 2     18
# 3     15
# 4     18
#       ..
# 85     3
# 86    17
# 87    13
# 88     2
# 89    10
# Name: DV, Length: 90, dtype: object

# %%
data[data['SECTION']=='BETA'].replace('o',0)
# Out:
#       S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 90    91.0    BETA  17   19  20   17  20   18
# 91    92.0    BETA  14    9  10   11  13   14
# 92    93.0    BETA  11   14  18   14  20   14
# 93    94.0    BETA  14    5  17    3  10   13
# 94    95.0    BETA  12   13  20    9  20   16
# ..     ...     ...  ..  ...  ..  ...  ..  ...
# 175  176.0    BETA  14    3  13    6  15   15
# 176  177.0    BETA   6    0  13    8  18   14
# 177  178.0    BETA  12   16  17    9  18   13
# 178  179.0    BETA  16   20  20   20  15   16
# 179  180.0    BETA  15    9  20    9  13   15
#
# [90 rows x 8 columns]

# %%
data[data['SECTION']=='BETA'].replace('A',0)
# Out:
#       S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 90    91.0    BETA  17   19  20   17  20   18
# 91    92.0    BETA  14    9  10   11  13   14
# 92    93.0    BETA  11   14  18   14  20   14
# 93    94.0    BETA  14    5  17    3  10   13
# 94    95.0    BETA  12   13  20    9  20   16
# ..     ...     ...  ..  ...  ..  ...  ..  ...
# 175  176.0    BETA  14    3  13    6  15   15
# 176  177.0    BETA   6    0  13    8  18   14
# 177  178.0    BETA  12   16  17    9  18   13
# 178  179.0    BETA  16   20  20   20  15   16
# 179  180.0    BETA  15    9  20    9  13   15
#
# [90 rows x 8 columns]

# %%
data['S.NO'] = range(1,len(data)+1)
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data = data.replace('MP',0)
data = data.replace('A',0)
data = data.replace('AB',0)
data = data.replace('o',0)
data = data.replace('II',11)
data = data.replace('I',1)

# %%
data['FL'] = data['FL'].fillna(0) 
data=data.dropna()

# %%
data.shape
# Out:
# (716, 8)

# %%
data.fillna(0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]>

# %%
data.isnull()
# Out:
#       S.NO  SECTION     DV   M-II     PP   BEEE     FL   FIMS
# 0    False    False  False  False  False  False  False  False
# 1    False    False  False  False  False  False  False  False
# 2    False    False  False  False  False  False  False  False
# 3    False    False  False  False  False  False  False  False
# 4    False    False  False  False  False  False  False  False
# ..     ...      ...    ...    ...    ...    ...    ...    ...
# 713  False    False  False  False  False  False  False  False
# 714  False    False  False  False  False  False  False  False
# 715  False    False  False  False  False  False  False  False
# 716  False    False  False  False  False  False  False  False
# 717  False    False  False  False  False  False  False  False
#
# [716 rows x 8 columns]

# %%
data.DV.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      12
# 1      19
# 2      18
# 3      15
# 4      18
#        ..
# 713    19
# 714    12
# 715    17
# 716    12
# 717    19
# Name: DV, Length: 716, dtype: object>

# %%
data.DV.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 713    False
# 714    False
# 715    False
# 716    False
# 717    False
# Name: DV, Length: 716, dtype: bool

# %%
data.rename(columns={'M-II':'Maths'})
# Out:
#      S.NO SECTION  DV Maths  PP BEEE  FL FIMS
# 0       1   ALPHA  12     0  17    9  19   15
# 1       2   ALPHA  19    12  16   16  18    3
# 2       3   ALPHA  18    14  18   18  18   16
# 3       4   ALPHA  15     9  19   17  19   15
# 4       5   ALPHA  18    17  19   19  20   18
# ..    ...     ...  ..   ...  ..  ...  ..  ...
# 713   714    ZETA  19     8   8   19  17   18
# 714   715    ZETA  12     1   7   10  20    8
# 715   716    ZETA  17     6  14   14  17   18
# 716   717    ZETA  12     1   6    7  15   12
# 717   718    ZETA  19    14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
data.PP.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      17
# 1      16
# 2      18
# 3      19
# 4      19
#        ..
# 713     8
# 714     7
# 715    14
# 716     6
# 717    17
# Name: PP, Length: 716, dtype: object>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       716 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 50.3+ KB

# %%
std_data=data.groupby(['SECTION']).std()
std_data
# Out:
# C:\Users\Harshini\AppData\Local\Temp\ipykernel_3100\2446702362.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   std_data=data.groupby(['SECTION']).std()
#               S.NO
# SECTION
# ALPHA    26.124701
# BETA     26.124701
# DELTA    26.124701
# EPSILON  25.547342
# GAMMA    26.124701
# OMEGA    26.124701
# SIGMA    18.468669
# ZETA     33.630343

# %%
std_data=data.groupby(['SECTION']).std()
std_data
# Out:
# C:\Users\Harshini\AppData\Local\Temp\ipykernel_3100\2446702362.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   std_data=data.groupby(['SECTION']).std()
#               S.NO
# SECTION
# ALPHA    26.124701
# BETA     26.124701
# DELTA    26.124701
# EPSILON  25.547342
# GAMMA    26.124701
# OMEGA    26.124701
# SIGMA    18.468669
# ZETA     33.630343

# %%
data[data['SECTION']=='ALPHA']['DV']
# Out:
# 0     12
# 1     19
# 2     18
# 3     15
# 4     18
#       ..
# 85     3
# 86    17
# 87    13
# 88     2
# 89    10
# Name: DV, Length: 90, dtype: object

# %%
data[data['SECTION']=='BETA']['DV']
# Out:
# 90     17
# 91     14
# 92     11
# 93     14
# 94     12
#        ..
# 175    14
# 176     6
# 177    12
# 178    16
# 179    15
# Name: DV, Length: 90, dtype: object

# %%
import scipy.stats as stats

# %%
data[data['SECTION']=='ALPHA'].DV.mean()
# Out:
# 1.3546461313016855e+160

# %%
import scipy.stats as stats

# %%
mean_data=data.groupby(['SECTION']).mean()
mean_data

# %%
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
columns_to_convert = ["DV","M-II","PP","BEEE","FL","FIMS"]
for col in columns_to_convert:
    data[col] = pd.to_numeric(data[col], errors='coerce')    
data["Total"] = data["DV"]+data["M-II"]+data["PP"]+data["BEEE"]+data["FL"]+data["FIMS"]
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total
# 0       1   ALPHA  12     0  17     9  19    15     72
# 1       2   ALPHA  19    12  16    16  18     3     84
# 2       3   ALPHA  18    14  18    18  18    16    102
# 3       4   ALPHA  15     9  19    17  19    15     94
# 4       5   ALPHA  18    17  19    19  20    18    111
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...
# 713   714    ZETA  19     8   8    19  17    18     89
# 714   715    ZETA  12     1   7    10  20     8     58
# 715   716    ZETA  17     6  14    14  17    18     86
# 716   717    ZETA  12     1   6     7  15    12     53
# 717   718    ZETA  19    14  17    16  20    19    105
#
# [716 rows x 9 columns]

# %%
data['backlogs'] = (data[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1)
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs
# 0       1   ALPHA  12     0  17     9  19    15     72         2
# 1       2   ALPHA  19    12  16    16  18     3     84         1
# 2       3   ALPHA  18    14  18    18  18    16    102         0
# 3       4   ALPHA  15     9  19    17  19    15     94         1
# 4       5   ALPHA  18    17  19    19  20    18    111         0
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 713   714    ZETA  19     8   8    19  17    18     89         2
# 714   715    ZETA  12     1   7    10  20     8     58         3
# 715   716    ZETA  17     6  14    14  17    18     86         1
# 716   717    ZETA  12     1   6     7  15    12     53         3
# 717   718    ZETA  19    14  17    16  20    19    105         0
#
# [716 rows x 10 columns]

# %%
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs
# 0       1   ALPHA  12     0  17     9  19    15     72         2
# 1       2   ALPHA  19    12  16    16  18     3     84         1
# 2       3   ALPHA  18    14  18    18  18    16    102         0
# 3       4   ALPHA  15     9  19    17  19    15     94         1
# 4       5   ALPHA  18    17  19    19  20    18    111         0
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 713   714    ZETA  19     8   8    19  17    18     89         2
# 714   715    ZETA  12     1   7    10  20     8     58         3
# 715   716    ZETA  17     6  14    14  17    18     86         1
# 716   717    ZETA  12     1   6     7  15    12     53         3
# 717   718    ZETA  19    14  17    16  20    19    105         0
#
# [716 rows x 10 columns]

# %%
data[data['DV']==20]
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs
# 11     12   ALPHA  20    20  20    20  19    16    115         0
# 23     24   ALPHA  20    20  20    20  20    18    118         0
# 39     40   ALPHA  20    17  20    19  20    18    114         0
# 69     70   ALPHA  20    20  20    19  20    18    117         0
# 115   116    BETA  20    20  20    20  20    17    117         0
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 648   649    ZETA  20    20  11    20  20    19    110         0
# 653   654    ZETA  20    20  16    20  20    18    114         0
# 692   693    ZETA  20    15  17    18  20    17    107         0
# 693   694    ZETA  20     1   8    20  18    18     85         2
# 694   695    ZETA  20    19  14    20  20    19    112         0
#
# [103 rows x 10 columns]

# %%
data.value_counts('DV')
# Out:
# DV
# 20    103
# 17     79
# 16     74
# 18     69
# 15     63
# 19     60
# 11     43
# 14     41
# 12     41
# 13     30
# 10     26
# 9      20
# 6      12
# 8      11
# 5      11
# 0      11
# 7       8
# 2       6
# 4       4
# 1       3
# 3       1
# dtype: int64

# %%
data[data['FIMS']==20]
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs
# 180   181   DELTA  19    19  19    17  20    20    114         0
# 182   183   DELTA  18    19  19    20  20    20    116         0
# 187   188   DELTA   8     0   5     3  10    20     46         4
# 188   189   DELTA  17    10  15    10  15    20     87         0
# 189   190   DELTA  18    13  20    13  18    20    102         0
# 191   192   DELTA  17    15  19    12  20    20    103         0
# 202   203   DELTA  18    17  18    11  20    20    104         0
# 204   205   DELTA  18    20  18    14  15    20    105         0
# 213   214   DELTA  14    13   5    12  13    20     77         1
# 215   216   DELTA  18    11  20    14  20    20    103         0
# 228   229   DELTA  18    11  19    10  20    20     98         0
# 229   230   DELTA  20    12  18    17  20    20    107         0
# 251   252   DELTA  20    20  20    19  20    20    119         0
# ...

# %%
data.value_counts('FIMS')
# Out:
# FIMS
# 18    97
# 16    80
# 15    77
# 17    68
# 19    60
# 14    53
# 13    46
# 9     40
# 20    32
# 12    31
# 11    30
# 10    24
# 0     23
# 8     16
# 5      9
# 7      6
# 6      6
# 3      6
# 4      5
# 1      4
# 2      3
# dtype: int64

# %%
data.describe()
# Out:
#              S.NO          DV        M-II          PP        BEEE          FL  \
# count  716.000000  716.000000  716.000000  716.000000  716.000000  716.000000
# mean   358.874302   14.787709    9.949721   12.769553   13.287709   15.544693
# std    207.361522    4.569545    6.599236    5.817381    5.783112    4.476132
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    179.750000   12.000000    4.000000    9.000000    9.000000   13.000000
# 50%    358.500000   16.000000   10.000000   14.000000   15.000000   16.000000
# 75%    537.250000   18.000000   16.000000   18.000000   18.000000   20.000000
# max    718.000000   20.000000   20.000000   20.000000   20.000000   20.000000
#
#              FIMS       Total    backlogs
# count  716.000000  716.000000  716.000000
# mean    14.047486   80.386872    1.393855
# std      4.709815   25.335341    1.536927
# min      0.000000    0.000000    0.000000
# 25%     12.000000   64.000000    0.000000
# ...

# %%
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs
# 0       1   ALPHA  12     0  17     9  19    15     72         2
# 1       2   ALPHA  19    12  16    16  18     3     84         1
# 2       3   ALPHA  18    14  18    18  18    16    102         0
# 3       4   ALPHA  15     9  19    17  19    15     94         1
# 4       5   ALPHA  18    17  19    19  20    18    111         0
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 713   714    ZETA  19     8   8    19  17    18     89         2
# 714   715    ZETA  12     1   7    10  20     8     58         3
# 715   716    ZETA  17     6  14    14  17    18     86         1
# 716   717    ZETA  12     1   6     7  15    12     53         3
# 717   718    ZETA  19    14  17    16  20    19    105         0
#
# [716 rows x 10 columns]

# %%
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs
# 0       1   ALPHA  12     0  17     9  19    15     72         2
# 1       2   ALPHA  19    12  16    16  18     3     84         1
# 2       3   ALPHA  18    14  18    18  18    16    102         0
# 3       4   ALPHA  15     9  19    17  19    15     94         1
# 4       5   ALPHA  18    17  19    19  20    18    111         0
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 713   714    ZETA  19     8   8    19  17    18     89         2
# 714   715    ZETA  12     1   7    10  20     8     58         3
# 715   716    ZETA  17     6  14    14  17    18     86         1
# 716   717    ZETA  12     1   6     7  15    12     53         3
# 717   718    ZETA  19    14  17    16  20    19    105         0
#
# [716 rows x 10 columns]

# %%
data.fillna(0)
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs
# 0       1   ALPHA  12     0  17     9  19    15     72         2
# 1       2   ALPHA  19    12  16    16  18     3     84         1
# 2       3   ALPHA  18    14  18    18  18    16    102         0
# 3       4   ALPHA  15     9  19    17  19    15     94         1
# 4       5   ALPHA  18    17  19    19  20    18    111         0
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 713   714    ZETA  19     8   8    19  17    18     89         2
# 714   715    ZETA  12     1   7    10  20     8     58         3
# 715   716    ZETA  17     6  14    14  17    18     86         1
# 716   717    ZETA  12     1   6     7  15    12     53         3
# 717   718    ZETA  19    14  17    16  20    19    105         0
#
# [716 rows x 10 columns]

# %%
def assign_grade(DV):
    if DV >= 18:
        return 'very good'
    elif DV >= 15:
        return 'good'
    elif DV >= 12:
        return 'Average'
    else:
        return 'Poor'

data['Ana_skills']=data['DV'].apply(assign_grade)
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 1       2   ALPHA  19    12  16    16  18     3     84         1  very good
# 2       3   ALPHA  18    14  18    18  18    16    102         0  very good
# 3       4   ALPHA  15     9  19    17  19    15     94         1       good
# 4       5   ALPHA  18    17  19    19  20    18    111         0  very good
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 713   714    ZETA  19     8   8    19  17    18     89         2  very good
# 714   715    ZETA  12     1   7    10  20     8     58         3    Average
# 715   716    ZETA  17     6  14    14  17    18     86         1       good
# 716   717    ZETA  12     1   6     7  15    12     53         3    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
# [716 rows x 11 columns]

# %%
data.value_counts('Ana_skills')
# Out:
# Ana_skills
# very good    232
# good         216
# Poor         156
# Average      112
# dtype: int64

# %%
def assign_grade(PP):
    if PP >= 18:
        return 'very good'
    elif PP>= 15:
        return 'good'
    elif PP>= 12:
        return 'Average'
    else:
        return 'Poor'

data['co_skills']=data['PP'].apply(assign_grade)
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 1       2   ALPHA  19    12  16    16  18     3     84         1  very good
# 2       3   ALPHA  18    14  18    18  18    16    102         0  very good
# 3       4   ALPHA  15     9  19    17  19    15     94         1       good
# 4       5   ALPHA  18    17  19    19  20    18    111         0  very good
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 713   714    ZETA  19     8   8    19  17    18     89         2  very good
# 714   715    ZETA  12     1   7    10  20     8     58         3    Average
# 715   716    ZETA  17     6  14    14  17    18     86         1       good
# 716   717    ZETA  12     1   6     7  15    12     53         3    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills
# 0         good
# 1         good
# ...

# %%
data.value_counts('co_skills')
# Out:
# co_skills
# Poor         285
# very good    199
# good         127
# Average      105
# dtype: int64

# %%
data['backlogs'].value_counts()
# Out:
# 0    273
# 1    172
# 2    121
# 3     69
# 4     43
# 5     23
# 6     15
# Name: backlogs, dtype: int64

# %%
data[data['backlogs']==6]
# Out:
#      S.NO  SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 82     83    ALPHA   2     0   2     0   0     0      4         6       Poor
# 244   245    DELTA   0     0   0     0   0     0      0         6       Poor
# 336   337  EPSILON   0     0   0     0   0     0      0         6       Poor
# 402   403    GAMMA   0     0   0     0   0     0      0         6       Poor
# 414   415    GAMMA   0     0   0     0   0     0      0         6       Poor
# 450   451    OMEGA   9     0   0     0   0     0      9         6       Poor
# 458   459    OMEGA   6     1   0     0   0     0      7         6       Poor
# 487   488    OMEGA   1     5   0     0   0     0      6         6       Poor
# 495   496    OMEGA   0     0   0     0   0     0      0         6       Poor
# 551   552    SIGMA   0     0   0     0   0     0      0         6       Poor
# 556   557    SIGMA   0     0   0     0   0     0      0         6       Poor
# ...

# %%
data.value_counts('backlogs')
# Out:
# backlogs
# 0    273
# 1    172
# 2    121
# 3     69
# 4     43
# 5     23
# 6     15
# dtype: int64

# %%
data[data['Total']==120]
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 505   506   OMEGA  20    20  20    20  20    20    120         0  very good
# 507   508   OMEGA  20    20  20    20  20    20    120         0  very good
# 574   575   SIGMA  20    20  20    20  20    20    120         0  very good
# 596   597   SIGMA  20    20  20    20  20    20    120         0  very good
#
#      co_skills
# 505  very good
# 507  very good
# 574  very good
# 596  very good

# %%
a = data[data['DV']<10]
a.value_counts('SECTION').sum()
a = data[data['DV']<10]
a.value_counts('SECTION')
# Out:
# SECTION
# ALPHA      17
# BETA       17
# DELTA      14
# GAMMA      11
# OMEGA      10
# ZETA        9
# SIGMA       5
# EPSILON     4
# dtype: int64

# %%
c=data.value_counts('SECTION')
c
# Out:
# SECTION
# ZETA       116
# ALPHA       90
# BETA        90
# DELTA       90
# GAMMA       90
# OMEGA       90
# EPSILON     88
# SIGMA       62
# dtype: int64

# %%
data[data["DV"]>10].value_counts
# Out:
# <bound method DataFrame.value_counts of      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 1       2   ALPHA  19    12  16    16  18     3     84         1  very good
# 2       3   ALPHA  18    14  18    18  18    16    102         0  very good
# 3       4   ALPHA  15     9  19    17  19    15     94         1       good
# 4       5   ALPHA  18    17  19    19  20    18    111         0  very good
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 713   714    ZETA  19     8   8    19  17    18     89         2  very good
# 714   715    ZETA  12     1   7    10  20     8     58         3    Average
# 715   716    ZETA  17     6  14    14  17    18     86         1       good
# 716   717    ZETA  12     1   6     7  15    12     53         3    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills
# ...

# %%
a = data[data['M-II']<10]
a.value_counts('SECTION').sum()
a = data[data['M-II']<10]
a.value_counts('SECTION')
# Out:
# SECTION
# ZETA       72
# EPSILON    64
# OMEGA      58
# GAMMA      46
# DELTA      45
# BETA       25
# SIGMA      19
# ALPHA      18
# dtype: int64

# %%
a = data[data['PP']<10]
a.value_counts('SECTION').sum()
a = data[data['PP']<10]
a.value_counts('SECTION')
# Out:
# SECTION
# ZETA       53
# EPSILON    49
# GAMMA      36
# DELTA      28
# OMEGA      16
# ALPHA      12
# SIGMA      11
# BETA        8
# dtype: int64

# %%
a = data[data['BEEE']<10]
a.value_counts('SECTION').sum()
a = data[data['BEEE']<10]
a.value_counts('SECTION')
# Out:
# SECTION
# DELTA      46
# BETA       41
# ZETA       25
# OMEGA      21
# EPSILON    17
# GAMMA      17
# SIGMA      16
# ALPHA       8
# dtype: int64

# %%
a = data[data['FL']<10]
a.value_counts('SECTION').sum()
a = data[data['FL']<10]
a.value_counts('SECTION')
# Out:
# SECTION
# ZETA       15
# OMEGA      12
# EPSILON     8
# GAMMA       2
# SIGMA       2
# ALPHA       1
# BETA        1
# DELTA       1
# dtype: int64

# %%
a = data[data['FIMS']<10]
a.value_counts('SECTION').sum()
a = data[data['FIMS']<10]
a.value_counts('SECTION')
# Out:
# SECTION
# GAMMA      23
# ALPHA      22
# EPSILON    22
# ZETA       22
# BETA       11
# OMEGA       7
# SIGMA       7
# DELTA       4
# dtype: int64

# %%
import matplotlib.pyplot as plt
a1=data.groupby('backlogs')['DV']
a1.hist(color = 'blue',figsize=[8,8],grid=False,bins=5)
plt.title("Backlogs of students in DV")
plt.xlabel(" DV")
plt.ylabel("backlogs")
plt.show()

# %% [markdown]
# Histogram for backlogs of students in DV

# %%
import matplotlib.pyplot as plt
a1=data.groupby('backlogs')['PP']
a1.hist(color = 'RED',figsize=[8,8],grid=False,bins=5)
plt.title("Backlogs of students in PP")
plt.xlabel("PP")
plt.ylabel("backlogs")
plt.show()

# %% [markdown]
# Histogram for backlogs of students in DV

# %%
data["percentage"]=(data["Total"]/120)*100
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 1       2   ALPHA  19    12  16    16  18     3     84         1  very good
# 2       3   ALPHA  18    14  18    18  18    16    102         0  very good
# 3       4   ALPHA  15     9  19    17  19    15     94         1       good
# 4       5   ALPHA  18    17  19    19  20    18    111         0  very good
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 713   714    ZETA  19     8   8    19  17    18     89         2  very good
# 714   715    ZETA  12     1   7    10  20     8     58         3    Average
# 715   716    ZETA  17     6  14    14  17    18     86         1       good
# 716   717    ZETA  12     1   6     7  15    12     53         3    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills  percentage
# 0         good   60.000000
# ...

# %%
def assign_grade(percentage):
    if percentage >= 90:
        return 'A'
    elif percentage >= 80:
        return 'B'
    elif percentage >= 70:
        return 'C'
    elif percentage >= 60:
        return 'D'
    else:
        return 'F'

data['Grade']=data['percentage'].apply(assign_grade)
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 1       2   ALPHA  19    12  16    16  18     3     84         1  very good
# 2       3   ALPHA  18    14  18    18  18    16    102         0  very good
# 3       4   ALPHA  15     9  19    17  19    15     94         1       good
# 4       5   ALPHA  18    17  19    19  20    18    111         0  very good
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 713   714    ZETA  19     8   8    19  17    18     89         2  very good
# 714   715    ZETA  12     1   7    10  20     8     58         3    Average
# 715   716    ZETA  17     6  14    14  17    18     86         1       good
# 716   717    ZETA  12     1   6     7  15    12     53         3    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills  percentage Grade
# ...

# %%
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 1       2   ALPHA  19    12  16    16  18     3     84         1  very good
# 2       3   ALPHA  18    14  18    18  18    16    102         0  very good
# 3       4   ALPHA  15     9  19    17  19    15     94         1       good
# 4       5   ALPHA  18    17  19    19  20    18    111         0  very good
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 713   714    ZETA  19     8   8    19  17    18     89         2  very good
# 714   715    ZETA  12     1   7    10  20     8     58         3    Average
# 715   716    ZETA  17     6  14    14  17    18     86         1       good
# 716   717    ZETA  12     1   6     7  15    12     53         3    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills  percentage Grade
# ...

# %%
DF=data.sort_values("Total",ascending=True)
DF
# Out:
#      S.NO  SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 556   557    SIGMA   0     0   0     0   0     0      0         6       Poor
# 551   552    SIGMA   0     0   0     0   0     0      0         6       Poor
# 244   245    DELTA   0     0   0     0   0     0      0         6       Poor
# 402   403    GAMMA   0     0   0     0   0     0      0         6       Poor
# 336   337  EPSILON   0     0   0     0   0     0      0         6       Poor
# ..    ...      ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 251   252    DELTA  20    20  20    19  20    20    119         0  very good
# 505   506    OMEGA  20    20  20    20  20    20    120         0  very good
# 574   575    SIGMA  20    20  20    20  20    20    120         0  very good
# 596   597    SIGMA  20    20  20    20  20    20    120         0  very good
# 507   508    OMEGA  20    20  20    20  20    20    120         0  very good
#
#      co_skills  percentage Grade
# ...

# %%
data.SECTION.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 713     ZETA
# 714     ZETA
# 715     ZETA
# 716     ZETA
# 717     ZETA
# Name: SECTION, Length: 716, dtype: object>

# %%
DF['DV']>10
DF.DV.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 556     0
# 551     0
# 244     0
# 402     0
# 336     0
#        ..
# 251    20
# 505    20
# 574    20
# 596    20
# 507    20
# Name: DV, Length: 716, dtype: int64>

# %%
DF
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 65     66   ALPHA   9    13   8    15  10    11     66         2       Poor
# 64     65   ALPHA  12    17  20    17  13     9     88         1    Average
# 63     64   ALPHA  11    20  20    19  13    13     96         0       Poor
# 62     63   ALPHA  12    10  18    15  10     4     69         1    Average
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 633   634    ZETA  20     6   7     9  16    19     77         3  very good
# 632   633    ZETA  19    14  16    15  20    16    100         0  very good
# 631   632    ZETA  14     4   9    16  19    15     77         2    Average
# 643   644    ZETA  12     3   3     9   6    12     45         4    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills  percentage Grade
# ...

# %%
a=data[data['SECTION']=='alpha']>10

# %%
d1=DF.DV.value_counts()<10
d1.count()
# Out:
# 21

# %%
d1.describe
# Out:
# <bound method NDFrame.describe of 20    False
# 17    False
# 16    False
# 18    False
# 15    False
# 19    False
# 11    False
# 14    False
# 12    False
# 13    False
# 10    False
# 9     False
# 6     False
# 0     False
# 8     False
# 5     False
# 7      True
# 2      True
# 4      True
# 1      True
# 3      True
# Name: DV, dtype: bool>

# %%
d1=DF.DV.value_counts()>10
d1.count()
# Out:
# 21

# %%
DF=data.sort_values("SECTION",ascending=True)
DF
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 65     66   ALPHA   9    13   8    15  10    11     66         2       Poor
# 64     65   ALPHA  12    17  20    17  13     9     88         1    Average
# 63     64   ALPHA  11    20  20    19  13    13     96         0       Poor
# 62     63   ALPHA  12    10  18    15  10     4     69         1    Average
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 633   634    ZETA  20     6   7     9  16    19     77         3  very good
# 632   633    ZETA  19    14  16    15  20    16    100         0  very good
# 631   632    ZETA  14     4   9    16  19    15     77         2    Average
# 643   644    ZETA  12     3   3     9   6    12     45         4    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills  percentage Grade
# ...

# %%
DF.tail()
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 633   634    ZETA  20     6   7     9  16    19     77         3  very good
# 632   633    ZETA  19    14  16    15  20    16    100         0  very good
# 631   632    ZETA  14     4   9    16  19    15     77         2    Average
# 643   644    ZETA  12     3   3     9   6    12     45         4    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#     co_skills  percentage Grade
# 633      Poor   64.166667     D
# 632      good   83.333333     B
# 631      Poor   64.166667     D
# 643      Poor   37.500000     F
# 717      good   87.500000     B

# %%
data
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 1       2   ALPHA  19    12  16    16  18     3     84         1  very good
# 2       3   ALPHA  18    14  18    18  18    16    102         0  very good
# 3       4   ALPHA  15     9  19    17  19    15     94         1       good
# 4       5   ALPHA  18    17  19    19  20    18    111         0  very good
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 713   714    ZETA  19     8   8    19  17    18     89         2  very good
# 714   715    ZETA  12     1   7    10  20     8     58         3    Average
# 715   716    ZETA  17     6  14    14  17    18     86         1       good
# 716   717    ZETA  12     1   6     7  15    12     53         3    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills  percentage Grade
# ...

# %%
import matplotlib.pyplot as plt
a1=data.groupby('Total')['DV']
a1.hist(color = 'blue',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 0-20 Marks")
plt.xlabel("Total Marks in DV")
plt.ylabel("Marks Obtained")
plt.show()

# %% [markdown]
# Very few students have scored more than 10 marks in DV

# %%
a1=data.groupby('Total')['PP']
a1.hist(color = 'yellow',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 0-20 Marks")
plt.ylabel(" Marks obtained")
plt.xlabel("Total marks in PP")
plt.show()

# %% [markdown]
# Many of the students scored only 10 marks in PP

# %%
a1=data.groupby('PP')['percentage']
a1.hist(color = 'black',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 0-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in PP")
plt.show()

# %% [markdown]
# Many Students have scored 50 percentage in PP

# %%
a1=data.groupby('Total')['BEEE']
a1.hist(color = 'green',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 0-20 Marks")
plt.xlabel("Total Marks ")
plt.ylabel("Marks in BEEE")
plt.show()

# %% [markdown]
# Most of the students scored above 10 marks in BEEE

# %%
a1=data.groupby('Total')['FL']
a1.hist(color = 'brown',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 0-20 Marks")
plt.xlabel("Total Marks ")
plt.ylabel("Marks Obtained")
plt.show()

# %% [markdown]
# Many of the students scored above 15 marks in FL

# %%
b=data.loc[(data['Total'] >= 20) & (data['Total'] <= 75)]
b=b.reset_index()
b
# Out:
#      index  S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs  \
# 0        0     1   ALPHA  12     0  17     9  19    15     72         2
# 1       20    21   ALPHA   4     2   5     3  16     9     39         5
# 2       25    26   ALPHA   6    10  10    11  13    10     60         1
# 3       27    28   ALPHA   5     4   3    12  13     5     42         4
# 4       29    30   ALPHA   8     2  11    10  13    12     56         2
# ..     ...   ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 246    701   702    ZETA  15     4   3    13  14    13     62         2
# 247    705   706    ZETA  16     0  11    16  20     0     63         2
# 248    710   711    ZETA  18     1   6    12  11     9     57         3
# 249    714   715    ZETA  12     1   7    10  20     8     58         3
# 250    716   717    ZETA  12     1   6     7  15    12     53         3
#
#     Ana_skills co_skills  percentage Grade
# 0      Average      good   60.000000     D
# ...

# %%
b=data.loc[(data['Grade']=='A') & (data['backlogs'] ==0)]
b=b.reset_index()
b
# Out:
#      index  S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs  \
# 0        4     5   ALPHA  18    17  19    19  20    18    111         0
# 1        9    10   ALPHA  18    19  20    20  20    15    112         0
# 2       10    11   ALPHA  17    18  20    18  20    18    111         0
# 3       11    12   ALPHA  20    20  20    20  19    16    115         0
# 4       14    15   ALPHA  19    20  20    20  18    12    109         0
# ..     ...   ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 103    626   627    ZETA  17    20  16    19  18    18    108         0
# 104    648   649    ZETA  20    20  11    20  20    19    110         0
# 105    653   654    ZETA  20    20  16    20  20    18    114         0
# 106    668   669    ZETA  17    19  17    18  20    18    109         0
# 107    694   695    ZETA  20    19  14    20  20    19    112         0
#
#     Ana_skills  co_skills  percentage Grade
# 0    very good  very good   92.500000     A
# ...

# %%
b=data.loc[(data['Grade']=='B') & (data['backlogs'] ==0)]
b=b.reset_index()
b
# Out:
#     index  S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs  \
# 0       2     3   ALPHA  18    14  18    18  18    16    102         0
# 1       7     8   ALPHA  17    17  19    20  19    13    105         0
# 2      16    17   ALPHA  15    17  18    17  17    13     97         0
# 3      21    22   ALPHA  14    10  19    17  19    17     96         0
# 4      22    23   ALPHA  17    17  20    20  18    13    105         0
# ..    ...   ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 95    692   693    ZETA  20    15  17    18  20    17    107         0
# 96    697   698    ZETA  18    15  15    20  20    19    107         0
# 97    698   699    ZETA  18    17  15    16  20    16    102         0
# 98    709   710    ZETA  19    17  12    17  20    16    101         0
# 99    717   718    ZETA  19    14  17    16  20    19    105         0
#
#    Ana_skills  co_skills  percentage Grade
# 0   very good  very good   85.000000     B
# ...

# %%
b.plot.scatter(x='DV',y='Total',color='green',s=40)
plt.title("20-75 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Students who scored good marks in DV have scored good marks in Total also

# %%
b.plot.scatter(x='M-II',y='Total',color='orange',s=40)
plt.title("20-75 Marks ANALYSIS")
plt.show()

# %% [markdown]
# None of the students have scored 20 marks in M-II

# %%
b.plot.scatter(x='BEEE',y='Total',color='black',s=40)
plt.title("20-75 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Few students have scored 20 marks in BEEE and many students got 10 marks

# %%
c=data.loc[(DF['Total'] >= 25) & (DF['Total'] <= 75)]
c=c.reset_index()
c
# Out:
#      index  S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs  \
# 0        0     1   ALPHA  12     0  17     9  19    15     72         2
# 1       20    21   ALPHA   4     2   5     3  16     9     39         5
# 2       25    26   ALPHA   6    10  10    11  13    10     60         1
# 3       27    28   ALPHA   5     4   3    12  13     5     42         4
# 4       29    30   ALPHA   8     2  11    10  13    12     56         2
# ..     ...   ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 243    701   702    ZETA  15     4   3    13  14    13     62         2
# 244    705   706    ZETA  16     0  11    16  20     0     63         2
# 245    710   711    ZETA  18     1   6    12  11     9     57         3
# 246    714   715    ZETA  12     1   7    10  20     8     58         3
# 247    716   717    ZETA  12     1   6     7  15    12     53         3
#
#     Ana_skills co_skills  percentage Grade
# 0      Average      good   60.000000     D
# ...

# %%
c.boxplot(by='DV', column =['Total'], grid = False,color='Green',figsize=[5,6])
plt.title("25-75 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many students got 10 marks in DV only few got 20 marks and they scored above 45 marks

# %%
c.boxplot(by='FL', column =['Total'], grid = False,color='orange',figsize=[5,6])
plt.title("25-75 Marks")
plt.ylabel("Total")

plt.show()

# %% [markdown]
# Many students got 10 marks in FL only few got 20 marks and they scored above 45 marks

# %%
c.boxplot(by='PP', column =['Total'], grid = False,color='brown',figsize=[5,6])
plt.title("25-75 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many students got 5 marks in PP only very few got 20 marks and they scored above 45 marks

# %%
c.boxplot(by='BEEE', column =['Total'], grid = False,color='black',figsize=[5,6])
plt.title("25-75 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many students got 5-10 marks in BEEE only few got 20 marks and they scored above 45 marks

# %%
d=data.loc[(data['Total']>=25) & (data['Total']<=75)]
d=d.reset_index()
d
# Out:
#      index  S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs  \
# 0        0     1   ALPHA  12     0  17     9  19    15     72         2
# 1       20    21   ALPHA   4     2   5     3  16     9     39         5
# 2       25    26   ALPHA   6    10  10    11  13    10     60         1
# 3       27    28   ALPHA   5     4   3    12  13     5     42         4
# 4       29    30   ALPHA   8     2  11    10  13    12     56         2
# ..     ...   ...     ...  ..   ...  ..   ...  ..   ...    ...       ...
# 243    701   702    ZETA  15     4   3    13  14    13     62         2
# 244    705   706    ZETA  16     0  11    16  20     0     63         2
# 245    710   711    ZETA  18     1   6    12  11     9     57         3
# 246    714   715    ZETA  12     1   7    10  20     8     58         3
# 247    716   717    ZETA  12     1   6     7  15    12     53         3
#
#     Ana_skills co_skills  percentage Grade
# 0      Average      good   60.000000     D
# ...

# %%
d.plot.line(x='DV',y='Total',color='red')
plt.title("Line Graph of DV")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many students have scored in between 5-15 marks

# %%
d.plot.line(x='FIMS',y='Total',color='Black')
plt.title("Line Graph of FIMS")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many students have scored in between 5-15 marks

# %%
d.plot.line(x='FL',y='Total',color='blue')
plt.title("Line Graph of FL")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many students have scored in between 10-15 marks

# %%
d.plot.line(x='BEEE',y='Total',color='orange')
plt.title("Line Graph of BEEE")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many students have scored in between 2-15 marks

# %%
data.plot()
plt.show()

# %%
plt.hist(data['DV'],color='red',edgecolor='black',bins=9)
plt.xlabel("Marks scored in DV")
plt.ylabel("No.of students")
plt.title("Histogram of DV")
# Out:
# Text(0.5, 1.0, 'Histogram of DV')

# %% [markdown]
# Above 200 Students have scored 20 marks in DV

# %%
plt.hist(data['FL'],color='blue',edgecolor='black',bins=9)
plt.xlabel("Marks scored in FL")
plt.ylabel("No.of students")
plt.title("Histogram of FL")
# Out:
# Text(0.5, 1.0, 'Histogram of FL')

# %% [markdown]
# Above 300 students scored 20 marks more than 100 students scored 15 marks in Fl

# %%
plt.hist(data['PP'],color='ORANGE',edgecolor='black',bins=9)
plt.xlabel("Marks scored in PP")
plt.ylabel("No.of students")
plt.title("Histogram of PP")
# Out:
# Text(0.5, 1.0, 'Histogram of PP')

# %% [markdown]
# More than 200 students scored 20 marks in PP and more than 100 students got 10 marks

# %%
data.plot.scatter(x = 'DV', y = 'Total',color='blue',s=30)
plt.title("Scatter Plot for DV")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for DV')

# %% [markdown]
# Students who have scored 20 marks in DV also scored 120 Marks

# %%
data.plot.scatter(x = 'PP', y = 'Total',color='PINK',s=30)
plt.title("Scatter Plot for PP")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for PP')

# %% [markdown]
# Students who have scored above 18 marks in PP also scored 120 Marks

# %%
data.plot.scatter(x = 'FIMS', y = 'Total',color='ORANGE',s=30)
plt.title("Scatter Plot for FIMS")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for FIMS')

# %% [markdown]
# Many of the students scored above 15 marks in FIMS and they got above 100 marks and some students got 120

# %%
data.boxplot(by='DV', column =['Total'], grid = False,color='Green')
plt.title("Boxplot of Q1")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Maximum of the students scored in between 10 to 20 and only few got 120 marks

# %%
data.boxplot(by='PP', column =['Total'], grid = False,color='black')
plt.title("Boxplot of PP")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Most of the students got 15 marks in PP and very few got 20 marks in PP

# %%
data.plot.line(x='DV',y='Total',color='orange')
plt.title("Line Graph of DV")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# Most of the Students got 20 marks in DV

# %%
data.plot.line(x='PP',y='Total',color='blue')
plt.title("Line Graph of PP")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# Most of the Students got 20 marks in DV

# %%
data.plot.line(x='BEEE',y='Total',color='pink')
plt.title("Line Graph of BEEE")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# Most of the students got 20 marks in BEEE

# %%
import pandas as pd
import  seaborn as sns

# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv("MIDMARKS(1).csv")
sns.histplot(data=data, x="DV")
# Out:
# <Axes: xlabel='DV', ylabel='Count'>

# %% [markdown]
# Histogram for DV marks using seaborn

# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv("MIDMARKS(1).csv")
sns.histplot(data=data, x="PP")
# Out:
# <Axes: xlabel='PP', ylabel='Count'>

# %% [markdown]
# Histogram for PP marks using seaborn

# %%
sns.histplot(data=data, x="PP")
# Out:
# <Axes: xlabel='PP', ylabel='Count'>

# %%
sns.histplot(data=data, x="FL")
# Out:
# <Axes: xlabel='FL', ylabel='Count'>

# %%
DF
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  backlogs Ana_skills  \
# 0       1   ALPHA  12     0  17     9  19    15     72         2    Average
# 65     66   ALPHA   9    13   8    15  10    11     66         2       Poor
# 64     65   ALPHA  12    17  20    17  13     9     88         1    Average
# 63     64   ALPHA  11    20  20    19  13    13     96         0       Poor
# 62     63   ALPHA  12    10  18    15  10     4     69         1    Average
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...       ...        ...
# 633   634    ZETA  20     6   7     9  16    19     77         3  very good
# 632   633    ZETA  19    14  16    15  20    16    100         0  very good
# 631   632    ZETA  14     4   9    16  19    15     77         2    Average
# 643   644    ZETA  12     3   3     9   6    12     45         4    Average
# 717   718    ZETA  19    14  17    16  20    19    105         0  very good
#
#      co_skills  percentage Grade
# ...

# %%
sns.histplot(data=DF, x="backlogs")
# Out:
# <Axes: xlabel='backlogs', ylabel='Count'>

# %%
sns.histplot(data=DF, x="Total")
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=DF, x="Grade")
# Out:
# <Axes: xlabel='Grade', ylabel='Count'>

# %%
sns.scatterplot(x='backlogs', y='DV', data=DF,color = 'red')
plt.show()

# %%
sns.scatterplot(x='Grade', y='DV', data=DF,color = 'blue')
plt.show()

# %%
sns.scatterplot(x='Total', y='DV', data=DF,color = 'green')
plt.show()

# %%
sns.scatterplot(x='backlogs', y='PP', data=DF,color = 'black')
plt.show()

# %%
sns.scatterplot(x='Total', y='FIMS', data=DF,color = 'blue')
plt.show()

# %%
sns.scatterplot(x='Grade', y='FL', data=DF,color = 'orange')
plt.show()

# %%
sns.lineplot(x='backlogs', y='DV', data=DF, color = 'green')
plt.show()

# %%
sns.lineplot(x='backlogs', y='FIMS', data=DF, color = 'orange')
plt.show()

# %%
sns.lineplot(x='backlogs', y='FIMS', data=DF, color = 'blue')
plt.show()

# %%
sns.lineplot(x='Grade', y='FIMS', data=DF, color = 'black')
plt.show()

# %%
sns.lineplot(x='Total', y='PP', data=DF, color = 'orange')
plt.show()

# %%
sns.barplot(x='backlogs', y='DV', data=DF,color="red")
plt.show()

# %% [markdown]
# Barplot for backlogs in DV

# %%
sns.barplot(x='Total', y='DV', data=DF,color="orange")
plt.show()

# %%
sns.barplot(x='Grade', y='DV', data=DF,color='black')
plt.show()

# %%
sns.barplot(x='backlogs', y='PP', data=DF, color = 'green')
plt.show()

# %%
sns.histplot(data=DF['backlogs'], bins=30,color = 'red')
plt.show()

# %%
sns.histplot(data=DF['Total'], bins=30,color = 'black')
plt.show()

# %%
import matplotlib.pyplot as plt
a1=DF.groupby('co_skills')['PP']
a1.hist(color = 'red',figsize=[8,8],grid=False,bins=5)
plt.title("co_skills students in DV")
plt.xlabel(" DV")
plt.ylabel("co_skills")
plt.show()

# %%
import matplotlib.pyplot as plt
a1=DF.groupby('Ana_skills')['PP']
a1.hist(color = 'blue',figsize=[8,8],grid=False,bins=5)
plt.title("Ana_skills students in DV")
plt.xlabel(" DV")
plt.ylabel("Ana_skills")
plt.show()

# %%
DF.value_counts('co_skills')
# Out:
# co_skills
# Poor         285
# very good    199
# good         127
# Average      105
# dtype: int64

# %%
performance_counts = DF['co_skills'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(performance_counts, labels=performance_counts.index, autopct='%1.2f%%',)
plt.title('Distribution of Perfomance')
plt.show()

# %%
performance_counts = DF['Ana_skills'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(performance_counts, labels=performance_counts.index, autopct='%1.2f%%',)
plt.title('Distribution of Perfomance')
plt.show()
